# %%
import time
from IPython.display import clear_output
import subprocess

while True:
    clear_output(wait=True)
    subprocess.run(["nvidia-smi"])
    # subprocess.run(["htop"])
    time.sleep(1)
